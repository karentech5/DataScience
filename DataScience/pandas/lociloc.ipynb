# %% [markdown]
# # Pandas `loc` vs `iloc`
# ## Detailed Comparison with Examples

# %%
import pandas as pd

# %%
data = {
    "ID": [101, 102, 103, 104],
    "Name": ["Ram", "Sita", "Hari", "Gita"],
    "Marks": [85, 90, 78, 92]
}

df = pd.DataFrame(data)
df
# Out:
#     ID  Name  Marks
# 0  101   Ram     85
# 1  102  Sita     90
# 2  103  Hari     78
# 3  104  Gita     92

# %% [markdown]
# ## `loc` – Label-based Indexing
#
# - `loc` is used to access data using **labels**
# - Labels can be:
#   - Index names
#   - Column names
# - **Both start and end values are included**

# %%
df.loc[1,"Name"]
# Out:
# 'Sita'

# %%
df.set_index("ID", inplace=True)
df
# Out:
#      Name  Marks
# ID
# 101   Ram     85
# 102  Sita     90
# 103  Hari     78
# 104  Gita     92

# %%
df.iloc[2,1]
# Out:
# np.int64(78)

# %%
df.iloc[1,:0]
# Out:
# Series([], Name: 102, dtype: object)

# %%
df.loc["Ram"] # access single rows it gets error because we have set index to ID column and Ram is not an index value
#Key Concept
# loc[] works with row labels (index names)
#iloc[] works with row numbers
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df.loc["Ram"] # access single rows it gets error because we have set index to ID column and Ram is not an index value
#       2 #Key Concept
#       3 # loc[] works with row labels (index names)
#       4 #iloc[] works with row numbers
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\indexing.py:1207, in _LocationIndexer.__getitem__(self, key)
#    1205 maybe_callable = com.apply_if_callable(key, self.obj)
#    1206 maybe_callable = self._raise_callable_usage(key, maybe_callable)
# -> 1207 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\indexing.py:1449, in _LocIndexer._getitem_axis(self, key, axis)
#    1447 # fall thru to straight lookup
#    1448 self._validate_key(key, axis)
# -> 1449 return self._get_label(key, axis=axis)
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\indexing.py:1399, in _LocIndexer._get_label(self, label, axis)
#    1397 def _get_label(self, label, axis: AxisInt):
#    1398     # GH#5567 this will fail if the label is not present in the axis.
# -> 1399     return self.obj.xs(label, axis=axis)
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\generic.py:4253, in NDFrame.xs(self, key, axis, level, drop_level)
#    4251             new_index = index[loc]
#    4252 else:
# -> 4253     loc = index.get_loc(key)
#    4255     if isinstance(loc, np.ndarray):
#    4256         if loc.dtype == np.bool_:
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\indexes\range.py:525, in RangeIndex.get_loc(self, key)
#     523         raise KeyError(key) from err
#     524 if isinstance(key, Hashable):
# --> 525     raise KeyError(key)
#     526 self._check_indexing_error(key)
#     527 raise KeyError(key)
#
# KeyError: 'Ram'

# %%
df.loc[[101, 103]] # access multiple rows
# Out:
#      Name  Marks
# ID
# 101   Ram     85
# 103  Hari     78

# %%
df.loc[101] #Access Specific Columns
# Out:
# Name     Ram
# Marks     85
# Name: 101, dtype: object

# %%
df
# Out:
#      Name  Marks
# ID
# 101   Ram     85
# 102  Sita     90
# 103  Hari     78
# 104  Gita     92

# %%
df.loc[101:103, ["Name", "Marks"]]
# Out:
#      Name  Marks
# ID
# 101   Ram     85
# 102  Sita     90
# 103  Hari     78

# %% [markdown]
# ## `iloc` – Integer Position-based Indexing
#
# - `iloc` uses **integer positions**
# - Index starts from **0**
# - **End value is excluded**
# - Similar to Python list slicing

# %%
df.set_index("Marks")
# Out:
#        Name
# Marks
# 85      Ram
# 90     Sita
# 78     Hari
# 92     Gita

# %%
df
# Out:
#      Name  Marks
# ID
# 101   Ram     85
# 102  Sita     90
# 103  Hari     78
# 104  Gita     92

# %%
df.iloc[[0, 2]] #multiple rows
# Out:
#      Name  Marks
# ID
# 101   Ram     85
# 103  Hari     78

# %%
df.iloc[1, 0] #Access Specific Row & Column
# Out:
# 'Sita'

# %%
df.iloc[0:3, 0:2] #Access Range of Rows & Columns
# Out:
#      Name  Marks
# ID
# 101   Ram     85
# 102  Sita     90
# 103  Hari     78

# %% [markdown]
# ## Comparison Table
#
# | Feature | loc | iloc |
# |------|-----|------|
# | Type | Label-based | Integer position-based |
# | Uses | Index & column names | Row & column numbers |
# | Range | End included | End excluded |
# | Similar to | Dictionary | Python list |
# | Example | df.loc[101] | df.iloc[0] |

# %% [markdown]
# ### Common Mistakes
#
# ❌ Using labels in `iloc`
# ```python
# df.iloc[101]   # Error

# %% [markdown]
# df.loc[0]   # KeyError

# %% [markdown]
# ---
#
# ## 📌 10. When to Use What? (Markdown Cell)
#
# ```markdown
# ### When to Use `loc`
# - When index has meaningful labels (ID, Name, Date)
# - When readability is important
#
# ### When to Use `iloc`
# - When working with positions
# - When index values are unknown
# - For fast slicing like arrays
